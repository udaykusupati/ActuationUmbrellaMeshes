# %%
from deployment import regular_grid

# %%
category = 'test_regulards'

# %%
degree = 3
rows = 2
cols = 1

# %%
import random
name = f'odu{random.randint(0,999):0>3}'
deployment = 'linear' # incremental

# %%
# deployed_units   = [[0]]
# undeployed_units = [[5, 3]]

# %%
# active_cells    = [du + uu for du,uu in zip(deployed_units, undeployed_units)]
# target_percents = [[100]*len(du) + [0]*len(uu) for du,uu in zip(deployed_units, undeployed_units)] # 0:undeployed | 100:deployed

# %%
active_cells    = [[0,1], [0,1]]
target_percents = [[100,0], [0,50]] # 0:undeployed | 100:deployed
steps = [2,3]

# %%
regular_grid(degree, rows, cols, category, name, steps, deployment, active_cells, target_percents, verbose=True)
# Out:
# PLATE CHARACTERISTIQUES:
# 	plate thickness   : 0.032740
# 	plate edge length : 0.327405
# Deployment
#
# ==== PHASE 01 ====
# active_cells    = [0, 1]
# target_percents = [100, 0]
# step 00/02 saved.
# step 01/02 saved.
# step 02/02 saved.
#
# ==== PHASE 02 ====
# active_cells    = [0, 1]
# target_percents = [0, 50]
# step 00/03 saved.
# step 01/03 saved.
# step 02/03 saved.
# step 03/03 saved.
#
# -> generate images for VonMises.
#   phase: 00
# 2D stresses images for step 00 successfully saved.
# 2D stresses images for step 01 successfully saved.
# 2D stresses images for step 02 successfully saved.
#   phase: 01
# 2D stresses images for step 01 successfully saved.
# 2D stresses images for step 02 successfully saved.
# 2D stresses images for step 03 successfully saved.
#   generate 1D images:
# stress curve done
# stress scatter done
# ordered stress scatter done
#   generate images for heights and energies.
# phase: 00
# 2D heights images for step 00 successfully saved.
# ...
