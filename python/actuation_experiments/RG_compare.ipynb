# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from images import generate_1D

# %%
# reload automaticaly external modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### **Results paths**

# %%
paths_all = []
with open("./paths.txt") as f:
    paths_all = f.read().splitlines()
for i,p in enumerate(paths_all):
    print(f'{i: >2}: {p}')
# Out:
#  0: outputs/presentation/1D/03_04_01_u0_d1
#  1: outputs/presentation/1D/03_04_01_u0_d1
#  2: outputs/presentation/1D/03_04_01_u0_d1
#  3: outputs/presentation/1D/03_04_01_u0_d1
#  4: outputs/presentation/1D/03_04_01_u0_d1
#  5: outputs/presentation/1D/03_04_01_u0_d2
#  6: outputs/presentation/1D/03_04_01_u0_d2
#  7: outputs/presentation/1D/03_04_01_u0_d2
#  8: outputs/presentation/1D/03_04_01_u0_d2
#  9: outputs/presentation/1D/03_04_01_u0_d2
# 10: outputs/presentation/1D/03_04_01_u0_d3
# 11: outputs/presentation/1D/03_04_01_u0_d3
# 12: outputs/presentation/1D/03_04_01_u0_d4
# 13: outputs/presentation/1D/03_04_01_u0_d4
# 14: outputs/presentation/1D/03_04_01_u0_d5
# 15: outputs/presentation/1D/03_04_01_u0_d5
# 16: outputs/presentation/1D/03_04_01_u0_d6
# 17: outputs/presentation/1D/03_04_01_u0_d6
# 18: outputs/presentation/1D/03_04_01_u0_d7
# 19: outputs/presentation/1D/03_04_01_u0_d7
# 20: outputs/presentation/1D/03_04_01_linear_heights
# ...

# %%
paths = paths_all[-2:]
paths = ['outputs/presentation/1D/03_01_04_linear_heights', 'outputs/presentation/1D/03_01_04_linear_heights']

# %%
deployments = ['incremental', 'linear']
save_dir = 'outputs/test'

# %%
generate_1D(paths, deployments, save_dir = save_dir, stress_type='maxBending', show_percent=False, show_plot=True)
